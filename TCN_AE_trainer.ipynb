# %%
# !conda activate DSU-FIN
import torch
import os
from torch.utils.data import DataLoader
import torch.nn as nn
import time
from TCN_AE_model_2 import CustomDataset, encoder_decoder_tcn
from bokeh.plotting import figure, show, curdoc
from bokeh.models import ColumnDataSource
from bokeh.io import output_notebook
from jupyter_bokeh.widgets import BokehModel

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print(f' Device: {torch.cuda.get_device_name(0)}. Now using: {device.type}', '\n',
      f'Torch Version: {torch.version.__version__}')

if not os.getcwd() == 'e:\\python_projects\\notebooks\\Deep learning\\FIN':
    os.chdir('e:\\python_projects\\notebooks\\Deep learning\\FIN')
# Out:
#  Device: NVIDIA GeForce RTX 4070 Ti. Now using: cuda
#  Torch Version: 2.7.1+cu128

# %%
output_notebook()

source = ColumnDataSource(data={
    'epoch': [],
    'Train_loss': [],
    'Val_loss': []
})
p = figure(
    title="Losses Over Epochs",
    x_axis_label="Epoch",
    y_axis_label="Loss Value",
    width=1000,
    height=400
)
p.line(x='epoch', y='Train_loss', source=source, color='green', legend_label='Train Loss')
p.line(x='epoch', y='Val_loss', source=source, color='purple', legend_label='Validation Loss')
p.legend.location = "bottom_left"
p.legend.click_policy = "hide"

bokeh_widget = BokehModel(p)
display(bokeh_widget)

hour = 4 * 60 # 4*15 seconds * 60
win_size_hours = 24
win_size = win_size_hours * hour
stride = hour * 6

BATCH_SIZE = 24
N_EPOCHS = 100

last_epoch = 0

train_dataset = CustomDataset('tina_train_15s.parquet', win_size = win_size, stride = stride)
val_dataset = CustomDataset('tina_val_15s.parquet', win_size = win_size, stride = stride)
model = encoder_decoder_tcn() 
model = model.to(device)
lr = 0.00005
wd = 0.000001

optimizer = torch.optim.AdamW(model.parameters(), 
                              lr = lr, 
                              weight_decay = wd
                              )
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=N_EPOCHS, eta_min=0.000005)  
criterion = nn.SmoothL1Loss(reduction='mean')
# criterion = nn.MSELoss(reduction='mean')

train_losses = []
val_losses = []
epochs = []

best_loss = torch.inf

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

for ep in range(last_epoch, last_epoch+N_EPOCHS):
    start = time.time()
    epoch_train_loss = 0
    model.train(True)
    batch_num = 0
    for x_batch, y_batch in train_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)

        optimizer.zero_grad()

        output = model(x_batch)
        loss = criterion(output, y_batch)
        epoch_train_loss += loss.item()
        loss.backward()
        optimizer.step()
        batch_num +=1

    avg_tr_loss = epoch_train_loss / len(train_loader)
    train_losses.append(avg_tr_loss)
    model.eval()
    total_val_loss = 0
    with torch.no_grad():
        for x_batch, y_batch in val_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            
            output = model(x_batch)
            loss = criterion(output, y_batch)
            total_val_loss += loss.item()

    avg_val_loss = total_val_loss / len(val_loader)
    last_lr = optimizer.param_groups[0]['lr']
       
        
    val_losses.append(avg_val_loss)
    epochs.append(ep+1)

    if avg_val_loss < best_loss:
        no_improve_counter = 0
        best_loss = avg_val_loss
        model_state_name = f'model states\\TCN-AE_15s_SL1.pth'
        optimizer_state_name = f'model states\\optimizer_TCN-AE_15s_SL1.pth'
        torch.save(model.state_dict(), model_state_name)
        torch.save(optimizer.state_dict(), optimizer_state_name)
        print(f"Best model saved at epoch: {ep+1}")
    # if ep+1 >=5:        
    lr_scheduler.step()
    # if ep+1 >=30:
    #     no_improve_counter +=1
    #     if no_improve_counter >=5:
    #         print(f'Early stopping at epoch {ep+1}')
    #         break
    
    end = time.time()
    epoch_duration = end - start
    print(f'Epoch {ep+1}. Train Loss: {avg_tr_loss:.6f}. Validation Loss: {avg_val_loss:.6f}. Last LR: {last_lr:.8f}. time: {epoch_duration: .2f}s')
  
    source.data = {
        'epoch': epochs,
        'Train_loss': train_losses,
        'Val_loss': val_losses
            }
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="da00877a-5c4a-4e7c-8d58-b430a01b7580">Loading BokehJS ...</span>
#     </div>
# BokehModel(render_bundle={'docs_json': {'b2edcd1d-f18f-4f14-8eb2-ff5cf250434b': {'version': '3.7.3', 'title': …
# Best model saved at epoch: 1
# Epoch 1. Train Loss: 1.211976. Validation Loss: 1.037946. Last LR: 0.00005000. time:  25.28s
# Epoch 2. Train Loss: 1.084794. Validation Loss: 1.051615. Last LR: 0.00004999. time:  24.72s
# Best model saved at epoch: 3
# Epoch 3. Train Loss: 1.042947. Validation Loss: 1.030520. Last LR: 0.00004996. time:  24.88s
# Best model saved at epoch: 4
# Epoch 4. Train Loss: 1.010016. Validation Loss: 0.987489. Last LR: 0.00004990. time:  24.83s
# Best model saved at epoch: 5
# Epoch 5. Train Loss: 0.979869. Validation Loss: 0.919657. Last LR: 0.00004982. time:  24.56s
# Best model saved at epoch: 6
# Epoch 6. Train Loss: 0.948251. Validation Loss: 0.863913. Last LR: 0.00004972. time:  25.05s
# Best model saved at epoch: 7
# Epoch 7. Train Loss: 0.921244. Validation Loss: 0.809757. Last LR: 0.00004960. time:  24.58s
# Best model saved at epoch: 8
# Epoch 8. Train Loss: 0.896023. Validation Loss: 0.753744. Last LR: 0.00004946. time:  24.54s
# Best model saved at epoch: 9
# Epoch 9. Train Loss: 0.874789. Validation Loss: 0.713572. Last LR: 0.00004929. time:  24.68s
# Epoch 10. Train Loss: 0.861339. Validation Loss: 0.759176. Last LR: 0.00004911. time:  24.44s
# Best model saved at epoch: 11
# Epoch 11. Train Loss: 0.859546. Validation Loss: 0.713048. Last LR: 0.00004890. time:  24.53s
# Best model saved at epoch: 12
# Epoch 12. Train Loss: 0.844756. Validation Loss: 0.681304. Last LR: 0.00004867. time:  24.72s
# Best model saved at epoch: 13
# Epoch 13. Train Loss: 0.829421. Validation Loss: 0.639965. Last LR: 0.00004842. time:  24.56s
# Epoch 14. Train Loss: 0.815697. Validation Loss: 0.640086. Last LR: 0.00004815. time:  24.52s
# Best model saved at epoch: 15
# Epoch 15. Train Loss: 0.807418. Validation Loss: 0.627268. Last LR: 0.00004786. time:  24.63s
# Best model saved at epoch: 16
# Epoch 16. Train Loss: 0.801262. Validation Loss: 0.591881. Last LR: 0.00004755. time:  24.91s
# Best model saved at epoch: 17
# Epoch 17. Train Loss: 0.791772. Validation Loss: 0.579422. Last LR: 0.00004722. time:  24.70s
# Epoch 18. Train Loss: 0.788001. Validation Loss: 0.609260. Last LR: 0.00004687. time:  24.74s
# Best model saved at epoch: 19
# Epoch 19. Train Loss: 0.781690. Validation Loss: 0.564583. Last LR: 0.00004650. time:  24.59s
# Best model saved at epoch: 20
# Epoch 20. Train Loss: 0.776648. Validation Loss: 0.558098. Last LR: 0.00004611. time:  24.57s
# Best model saved at epoch: 21
# Epoch 21. Train Loss: 0.771137. Validation Loss: 0.551155. Last LR: 0.00004570. time:  24.46s
# Best model saved at epoch: 22
# Epoch 22. Train Loss: 0.765927. Validation Loss: 0.540668. Last LR: 0.00004528. time:  24.52s
# Best model saved at epoch: 23
# Epoch 23. Train Loss: 0.762183. Validation Loss: 0.534296. Last LR: 0.00004484. time:  24.54s
# Best model saved at epoch: 24
# Epoch 24. Train Loss: 0.758122. Validation Loss: 0.530413. Last LR: 0.00004438. time:  24.76s
# Epoch 25. Train Loss: 0.756681. Validation Loss: 0.542082. Last LR: 0.00004390. time:  24.58s
# Best model saved at epoch: 26
# Epoch 26. Train Loss: 0.753505. Validation Loss: 0.524852. Last LR: 0.00004341. time:  24.60s
# Best model saved at epoch: 27
# Epoch 27. Train Loss: 0.749038. Validation Loss: 0.517784. Last LR: 0.00004290. time:  24.52s
# Epoch 28. Train Loss: 0.746820. Validation Loss: 0.525267. Last LR: 0.00004238. time:  24.50s
# Best model saved at epoch: 29
# Epoch 29. Train Loss: 0.741364. Validation Loss: 0.510946. Last LR: 0.00004184. time:  24.55s
# Epoch 30. Train Loss: 0.738189. Validation Loss: 0.512487. Last LR: 0.00004129. time:  24.89s
# Best model saved at epoch: 31
# Epoch 31. Train Loss: 0.735037. Validation Loss: 0.501809. Last LR: 0.00004073. time:  25.91s
# Best model saved at epoch: 32
# Epoch 32. Train Loss: 0.730679. Validation Loss: 0.498004. Last LR: 0.00004015. time:  25.24s
# Epoch 33. Train Loss: 0.727986. Validation Loss: 0.498796. Last LR: 0.00003956. time:  24.45s
# Best model saved at epoch: 34
# Epoch 34. Train Loss: 0.725633. Validation Loss: 0.490877. Last LR: 0.00003895. time:  24.43s
# Epoch 35. Train Loss: 0.723455. Validation Loss: 0.494922. Last LR: 0.00003834. time:  24.46s
# Epoch 36. Train Loss: 0.722012. Validation Loss: 0.491068. Last LR: 0.00003771. time:  24.55s
# Best model saved at epoch: 37
# Epoch 37. Train Loss: 0.719318. Validation Loss: 0.484929. Last LR: 0.00003708. time:  24.63s
# Epoch 38. Train Loss: 0.718396. Validation Loss: 0.487980. Last LR: 0.00003644. time:  24.43s
# Epoch 39. Train Loss: 0.716539. Validation Loss: 0.491875. Last LR: 0.00003578. time:  24.68s
# Best model saved at epoch: 40
# Epoch 40. Train Loss: 0.715224. Validation Loss: 0.478500. Last LR: 0.00003512. time:  24.61s
# Epoch 41. Train Loss: 0.713570. Validation Loss: 0.482047. Last LR: 0.00003445. time:  24.48s
# Epoch 42. Train Loss: 0.712016. Validation Loss: 0.486570. Last LR: 0.00003378. time:  24.58s
# Best model saved at epoch: 43
# Epoch 43. Train Loss: 0.709862. Validation Loss: 0.476695. Last LR: 0.00003310. time:  24.64s
# Best model saved at epoch: 44
# Epoch 44. Train Loss: 0.708080. Validation Loss: 0.475975. Last LR: 0.00003241. time:  24.55s
# Epoch 45. Train Loss: 0.706199. Validation Loss: 0.478305. Last LR: 0.00003172. time:  24.60s
# Best model saved at epoch: 46
# Epoch 46. Train Loss: 0.704677. Validation Loss: 0.475033. Last LR: 0.00003102. time:  24.62s
# Best model saved at epoch: 47
# Epoch 47. Train Loss: 0.703432. Validation Loss: 0.473017. Last LR: 0.00003032. time:  24.75s
# Epoch 48. Train Loss: 0.702555. Validation Loss: 0.473878. Last LR: 0.00002962. time:  24.81s
# Best model saved at epoch: 49
# Epoch 49. Train Loss: 0.701690. Validation Loss: 0.467643. Last LR: 0.00002891. time:  24.75s
# Epoch 50. Train Loss: 0.700915. Validation Loss: 0.469378. Last LR: 0.00002821. time:  24.54s
# Epoch 51. Train Loss: 0.699319. Validation Loss: 0.471307. Last LR: 0.00002750. time:  24.52s
# Best model saved at epoch: 52
# Epoch 52. Train Loss: 0.697341. Validation Loss: 0.464535. Last LR: 0.00002679. time:  25.13s
# Best model saved at epoch: 53
# Epoch 53. Train Loss: 0.696337. Validation Loss: 0.462951. Last LR: 0.00002609. time:  25.81s
# Epoch 54. Train Loss: 0.694733. Validation Loss: 0.465641. Last LR: 0.00002538. time:  24.52s
# Best model saved at epoch: 55
# Epoch 55. Train Loss: 0.694469. Validation Loss: 0.462467. Last LR: 0.00002468. time:  24.62s
# Best model saved at epoch: 56
# Epoch 56. Train Loss: 0.693428. Validation Loss: 0.460553. Last LR: 0.00002398. time:  24.61s
# Epoch 57. Train Loss: 0.692596. Validation Loss: 0.464174. Last LR: 0.00002328. time:  24.54s
# Best model saved at epoch: 58
# Epoch 58. Train Loss: 0.691516. Validation Loss: 0.459745. Last LR: 0.00002259. time:  24.57s
# Best model saved at epoch: 59
# Epoch 59. Train Loss: 0.690220. Validation Loss: 0.455781. Last LR: 0.00002190. time:  25.11s
# Epoch 60. Train Loss: 0.689357. Validation Loss: 0.457006. Last LR: 0.00002122. time:  25.78s
# Epoch 61. Train Loss: 0.688219. Validation Loss: 0.457816. Last LR: 0.00002055. time:  24.60s
# Best model saved at epoch: 62
# Epoch 62. Train Loss: 0.687519. Validation Loss: 0.455005. Last LR: 0.00001988. time:  24.91s
# Best model saved at epoch: 63
# Epoch 63. Train Loss: 0.686713. Validation Loss: 0.453951. Last LR: 0.00001922. time:  24.85s
# Best model saved at epoch: 64
# Epoch 64. Train Loss: 0.686075. Validation Loss: 0.453604. Last LR: 0.00001856. time:  24.90s
# Best model saved at epoch: 65
# Epoch 65. Train Loss: 0.685382. Validation Loss: 0.452473. Last LR: 0.00001792. time:  25.20s
# Epoch 66. Train Loss: 0.684653. Validation Loss: 0.453220. Last LR: 0.00001729. time:  24.69s
# Best model saved at epoch: 67
# Epoch 67. Train Loss: 0.684098. Validation Loss: 0.451973. Last LR: 0.00001666. time:  24.89s
# Best model saved at epoch: 68
# Epoch 68. Train Loss: 0.683472. Validation Loss: 0.450081. Last LR: 0.00001605. time:  24.80s
# Epoch 69. Train Loss: 0.682887. Validation Loss: 0.450134. Last LR: 0.00001544. time:  24.47s
# Epoch 70. Train Loss: 0.682293. Validation Loss: 0.450929. Last LR: 0.00001485. time:  24.55s
# Best model saved at epoch: 71
# Epoch 71. Train Loss: 0.681814. Validation Loss: 0.448983. Last LR: 0.00001427. time:  24.63s
# Best model saved at epoch: 72
# Epoch 72. Train Loss: 0.681293. Validation Loss: 0.448077. Last LR: 0.00001371. time:  24.55s
# Epoch 73. Train Loss: 0.680886. Validation Loss: 0.448827. Last LR: 0.00001316. time:  24.48s
# Epoch 74. Train Loss: 0.680339. Validation Loss: 0.448144. Last LR: 0.00001262. time:  24.73s
# Best model saved at epoch: 75
# Epoch 75. Train Loss: 0.679929. Validation Loss: 0.446952. Last LR: 0.00001210. time:  24.56s
# Epoch 76. Train Loss: 0.679530. Validation Loss: 0.446975. Last LR: 0.00001159. time:  24.76s
# Best model saved at epoch: 77
# Epoch 77. Train Loss: 0.679103. Validation Loss: 0.446798. Last LR: 0.00001110. time:  25.01s
# Best model saved at epoch: 78
# Epoch 78. Train Loss: 0.678703. Validation Loss: 0.445936. Last LR: 0.00001062. time:  25.46s
# Best model saved at epoch: 79
# Epoch 79. Train Loss: 0.678294. Validation Loss: 0.445806. Last LR: 0.00001016. time:  24.58s
# Best model saved at epoch: 80
# Epoch 80. Train Loss: 0.677945. Validation Loss: 0.445556. Last LR: 0.00000972. time:  24.63s
# Best model saved at epoch: 81
# Epoch 81. Train Loss: 0.677635. Validation Loss: 0.444922. Last LR: 0.00000930. time:  24.52s
# Best model saved at epoch: 82
# Epoch 82. Train Loss: 0.677293. Validation Loss: 0.444791. Last LR: 0.00000889. time:  24.72s
# Best model saved at epoch: 83
# Epoch 83. Train Loss: 0.676994. Validation Loss: 0.444636. Last LR: 0.00000850. time:  24.70s
# Best model saved at epoch: 84
# Epoch 84. Train Loss: 0.676676. Validation Loss: 0.444340. Last LR: 0.00000813. time:  24.57s
# Best model saved at epoch: 85
# Epoch 85. Train Loss: 0.676369. Validation Loss: 0.443878. Last LR: 0.00000778. time:  24.56s
# Best model saved at epoch: 86
# Epoch 86. Train Loss: 0.676151. Validation Loss: 0.443502. Last LR: 0.00000745. time:  24.64s
# Best model saved at epoch: 87
# Epoch 87. Train Loss: 0.675871. Validation Loss: 0.443387. Last LR: 0.00000714. time:  24.87s
# Epoch 88. Train Loss: 0.675552. Validation Loss: 0.443465. Last LR: 0.00000685. time:  24.97s
# Best model saved at epoch: 89
# Epoch 89. Train Loss: 0.675299. Validation Loss: 0.443067. Last LR: 0.00000658. time:  24.99s
# Best model saved at epoch: 90
# Epoch 90. Train Loss: 0.675065. Validation Loss: 0.442680. Last LR: 0.00000633. time:  24.67s
# Best model saved at epoch: 91
# Epoch 91. Train Loss: 0.674860. Validation Loss: 0.442456. Last LR: 0.00000610. time:  24.82s
# Best model saved at epoch: 92
# Epoch 92. Train Loss: 0.674598. Validation Loss: 0.442406. Last LR: 0.00000589. time:  24.55s
# Best model saved at epoch: 93
# Epoch 93. Train Loss: 0.674277. Validation Loss: 0.442327. Last LR: 0.00000571. time:  24.86s
# Best model saved at epoch: 94
# Epoch 94. Train Loss: 0.674093. Validation Loss: 0.442011. Last LR: 0.00000554. time:  24.57s
# Best model saved at epoch: 95
# Epoch 95. Train Loss: 0.673910. Validation Loss: 0.441682. Last LR: 0.00000540. time:  24.54s
# Epoch 96. Train Loss: 0.673676. Validation Loss: 0.441715. Last LR: 0.00000528. time:  24.38s
# Best model saved at epoch: 97
# Epoch 97. Train Loss: 0.673425. Validation Loss: 0.441650. Last LR: 0.00000518. time:  24.49s
# Best model saved at epoch: 98
# Epoch 98. Train Loss: 0.673305. Validation Loss: 0.441115. Last LR: 0.00000510. time:  24.73s
# Best model saved at epoch: 99
# Epoch 99. Train Loss: 0.673027. Validation Loss: 0.441023. Last LR: 0.00000504. time:  24.95s
# Best model saved at epoch: 100
# Epoch 100. Train Loss: 0.672778. Validation Loss: 0.440935. Last LR: 0.00000501. time:  24.91s

# %%
from bokeh.io import export_png
export_png(p, filename="Model training MSE.png")
# Out:
# 'e:\\python_projects\\notebooks\\Deep learning\\FIN\\Model training MSE.png'
